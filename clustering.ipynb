# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
features = pd.read_csv('Dataset/pros_features.csv')
targets = pd.read_csv('Dataset/pros_targets.csv')

# %%
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, random_state = 42)
    kmeans.fit(features)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss, marker = 'o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (k)')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Choosing k = 6

# %%
kmeans = KMeans(n_clusters = 6, random_state = 42)
features['Clusters'] = kmeans.fit_predict(features)

# %%
plt.scatter(features.iloc[:, 7], features.iloc[:, 12], c = features['Clusters'], cmap = 'viridis')
plt.title('Clusters')
plt.xlabel('7th col')
plt.ylabel('12th col')
plt.show()

# %%
features.to_csv('Dataset/data_with_clusters.csv', index = False)
